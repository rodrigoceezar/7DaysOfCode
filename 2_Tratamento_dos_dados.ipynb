# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# ### Importando os dados

# %%
dados_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %% [markdown]
# Os dados carregados são dados de empréstimos dos acervos do sistema de bibliotecas da UFRN dos anos de 2010 até o primeiro semestre de 2020.

# %% [markdown]
# ### Concatenando os dados

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# 3        2.007211e+08      ALUNO DE GRADUAÇÃO
# 4        2.008023e+09      ALUNO DE GRADUAÇÃO

# %% [markdown]
# Ao concatenar os dados, os dados vão ser unidos em um só dataframe e os dados serão ordenados um em baixo do outro, aumentando o número de linhas do dataframe.

# %%
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
dados_exemplares.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
df = emprestimos_biblioteca.merge(dados_exemplares)
df.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709684       L095049                            NaN
# 2         726965       L095049  2010/03/31 12:41:08.684000000
# 3         709685       L167050                            NaN
# 4         709685       L167050                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 2  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 3  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 4  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 2        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 3        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          630
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema
# 0              4225
# 1              4225
# 2              4225
# 3             25009
# 4             25009

# %% [markdown]
# Após ter unido todos os dados a serem analisados, é necessário tratar esses dados, para verificar os tipos dos dados, os dados nulos e os dados duplicados.

# %% [markdown]
# ### Entendendo os dados

# %%
# Criando uma cópia dos dados para fins de organização do ciclo.
df1 = df.copy()

# %%
df1.shape
# Out:
# (2072558, 13)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2072558 entries, 0 to 2072557
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 221.4+ MB

# %% [markdown]
# O conjunto de dados possui 2.072.558 registros e 13 caracteristicas dos empretismos feitos da biblioteca da Universidade Federal do Rio Grande do Norte, dos últimos 10 anos. A princípio, verificou-se que deve ser feita a transformação dos tipos de dados.

# %% [markdown]
# ### Analisando os dados duplicados

# %%
dados_duplicados = df1.loc[df.duplicated()]

# %%
cols = ['id_emprestimo','matricula_ou_siape']
dados_duplicados.loc[:,cols].groupby(['matricula_ou_siape']).count()
# Out:
#                     id_emprestimo
# matricula_ou_siape
# 2.007211e+08                    1
# 2.008010e+09                   12
# 2.008023e+09                    2
# 2.008112e+09                    1
# 2.009047e+09                    2
# 2.014036e+09                    2
# 2.015022e+09                    1
# 2.015316e+09                    3
# 2.016089e+09                    1
# 2.016013e+10                    2
# 2.016014e+10                    1
# 2.016014e+10                    1
# 2.016014e+10                    1
# 2.016101e+10                    2
# 2.016101e+10                    3
# 2.017005e+10                    1

# %% [markdown]
# Conclusão: Após essa análise preliminar, verificou-se que é possível apenas um aluno solicitar mais uma vez o emprestimo de um livro. Ante o exposto, até este momento não serão removidos esses dados duplicados.

# %% [markdown]
# ### Analisando os dados nulos

# %%
df1.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1162088
# data_emprestimo               0
# data_devolucao             6178
# matricula_ou_siape         2893
# tipo_vinculo_usuario          0
# id_exemplar                   0
# colecao                       0
# biblioteca                    0
# status_material               0
# localizacao                   0
# registro_sistema              0
# dtype: int64

# %%
df_aux = df.loc[df.matricula_ou_siape.isnull()]
df_aux.head()
# Out:
#       id_emprestimo codigo_barras                 data_renovacao  \
# 2647        2323664    2006035031  2016/11/25 14:05:14.497000000
# 3596         889199    2008053728                            NaN
# 7229         744030       L197755  2010/04/24 14:03:22.937000000
# 8253         757318    2006026894  2010/04/29 20:12:28.515000000
# 8570         803137    2008010964  2010/07/29 07:37:03.428000000
#
#                     data_emprestimo                 data_devolucao  \
# 2647  2016/10/20 12:43:53.545000000  2016/12/12 12:08:23.000000000
# 3596  2010/12/21 09:01:37.557000000  2010/12/27 09:49:14.000000000
# 7229  2010/03/25 15:07:52.629000000  2010/05/24 15:04:37.896000000
# 8253  2010/04/15 16:41:46.105000000  2010/05/12 17:33:41.741000000
# 8570  2010/07/14 18:26:51.664000000  2010/08/10 19:57:32.000000000
#
#       matricula_ou_siape             tipo_vinculo_usuario  id_exemplar  \
# 2647                 NaN                  USUÁRIO EXTERNO       212890
# 3596                 NaN  SERVIDOR TÉCNICO-ADMINISTRATIVO       257219
# 7229                 NaN                  USUÁRIO EXTERNO       129760
# 8253                 NaN  SERVIDOR TÉCNICO-ADMINISTRATIVO       205799
# 8570                 NaN  SERVIDOR TÉCNICO-ADMINISTRATIVO       240313
#
#                 colecao                      biblioteca status_material  \
# 2647  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 3596  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 7229  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 8253  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 8570  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
#
#       localizacao  registro_sistema
# 2647          686             85700
# 3596          641            110728
# 7229          625             43571
# 8253          615             82003
# 8570          661             99806

# %%
cols = ['tipo_vinculo_usuario','id_emprestimo']
df_aux.loc[:,cols].groupby('tipo_vinculo_usuario').count()
# Out:
#                                  id_emprestimo
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                         100
# ALUNO DE PÓS-GRADUAÇÃO                      88
# DOCENTE                                     45
# DOCENTE EXTERNO                              7
# OUTROS                                       5
# SERVIDOR TÉCNICO-ADMINISTRATIVO            187
# USUÁRIO EXTERNO                           2461

# %% [markdown]
# Conclusão: O valores nulos sempre requerem uma certa atenção quanto ao seu tratamento, eles podem ser tratados da seguinte forma: 1. Substituindo por valores especificos; 2. Usando a média, mediana ou a moda; 3. Removendo os valores.
#
# - A metodologia utilizada para o tratamento dos dados nulos da presente análise será:
# 1. Coluna data_renovação: Serão substituído pelo numeral 0, visto que no entendimento dos dados apresentados, quando não se tem dados da data de renovação, isso significa que o livro/exemplar não foi renovado.
# 2. Coluna data_devolução: Serão também substituídos por 0, tendo como entendimento que as linhas onde esteja nula são os livros que não foram devolvidos.
# 3. Coluna matricula_ou_siape: Após análise acima, verificou-se que os dados onde matricula_ou_siape esteja nulo podem ser os dados de usuários externos e outros, totalizando **2.648** emprestimos por pessoas sem número de matrícula, ou seja, sem vínculo. A priori, serão removidos esses dados, em outro ciclo poderá ser incluído na análise.
#
# OBS: Após se aprofundar mais na análise, poderão ser feitas outras modificações.

# %% [markdown]
# ### Tratando os dados nulos

# %%
# Preencher os dados nulos da coluna data_renovação por 0
df1['data_renovacao'] = df1['data_renovacao'].fillna(0)

# Preencher os dados nulos da coluna data_devolução por 0
df1['data_devolucao'] = df1['data_devolucao'].fillna(0)

# Remover os dados nulos da coluna matricula_ou_siape
df1.dropna(subset=['matricula_ou_siape'], inplace=True)

# %%
df1.isnull().sum()
# Out:
# id_emprestimo           0
# codigo_barras           0
# data_renovacao          0
# data_emprestimo         0
# data_devolucao          0
# matricula_ou_siape      0
# tipo_vinculo_usuario    0
# id_exemplar             0
# colecao                 0
# biblioteca              0
# status_material         0
# localizacao             0
# registro_sistema        0
# dtype: int64

# %% [markdown]
# ### Transformação dos dados

# %%
df1.dtypes
# Out:
# id_emprestimo             int64
# codigo_barras            object
# data_renovacao           object
# data_emprestimo          object
# data_devolucao           object
# matricula_ou_siape      float64
# tipo_vinculo_usuario     object
# id_exemplar               int64
# colecao                  object
# biblioteca               object
# status_material          object
# localizacao               int64
# registro_sistema          int64
# dtype: object

# %%
# Transformando para DateTime
df1['data_renovacao'] = pd.to_datetime(df['data_renovacao'], format='%Y/%m/%d')
df1['data_emprestimo'] = pd.to_datetime(df['data_emprestimo'], format='%Y/%m/%d')
df1['data_devolucao'] = pd.to_datetime(df['data_devolucao'], format='%Y/%m/%d')

# %%
df1.dtypes
# Out:
# id_emprestimo                    int64
# codigo_barras                   object
# data_renovacao          datetime64[ns]
# data_emprestimo         datetime64[ns]
# data_devolucao          datetime64[ns]
# matricula_ou_siape             float64
# tipo_vinculo_usuario            object
# id_exemplar                      int64
# colecao                         object
# biblioteca                      object
# status_material                 object
# localizacao                      int64
# registro_sistema                 int64
# dtype: object

# %% [markdown]
# ### Perguntas #1 Days Of Code

# %% [markdown]
# #### A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?

# %%
df1.head(2)
# Out:
#    id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 0         709684       L095049            NaT 2010-01-04 07:44:10.721
# 1         709684       L095049            NaT 2010-01-04 07:44:10.721
#
#            data_devolucao  matricula_ou_siape tipo_vinculo_usuario  \
# 0 2010-01-05 16:26:12.662        2.008023e+09   ALUNO DE GRADUAÇÃO
# 1 2010-01-05 16:26:12.662        2.008023e+09   ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao                      biblioteca  \
# 0        13259  Acervo Circulante  Biblioteca Central Zila Mamede
# 1        13259  Acervo Circulante  Biblioteca Central Zila Mamede
#
#   status_material  localizacao  registro_sistema
# 0         REGULAR          630              4225
# 1         REGULAR          630              4225

# %%
df_aux = df1.copy()

df_aux['ano'] = df_aux.data_emprestimo.dt.year
cols = ['ano', 'id_emprestimo']

graph1 = df_aux.loc[:,cols].groupby(['ano']).count().sort_values(by='ano', ascending=False).reset_index()

plt.figure(figsize=(20,8))
plt.subplot( 1, 2, 1 )
sns.barplot(x='ano', y='id_emprestimo', data=graph1)

plt.subplot( 1, 2, 2 )
sns.regplot(x='ano', y='id_emprestimo', data=graph1, scatter=False)
plt.show()

# %% [markdown]
# Conclusão: Nota-se que ao decorrer dos anos o número de emprestimos diminuiu. Observa-se uma grande diminuição em 2020, mas isso se dá pelo fato de termos apenas os dados do primeiro semestre de 2020. O que nos faz pensar, será que há uma diferença tão grande de emprestimos no 1º e no 2º semestre?

# %% [markdown]
# #### Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?

# %%
cols = ['id_emprestimo', 'biblioteca']

graph2 = df1.loc[:,cols].groupby('biblioteca').count().sort_values('id_emprestimo', ascending=False).reset_index().head(10)

ax = sns.barplot(x='biblioteca', y='id_emprestimo', data=graph2)

# Tamanho do plot
plt.figure(figsize=(10,20))

# Formatando os rótulos dos eixos y para o formato brasileiro
formatter = ticker.StrMethodFormatter("{x:,.2f}")
ax.yaxis.set_major_formatter(formatter)

# Definindo os rótulos do eixo x de forma horizontal
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

plt.show()
# Out:
# <ipython-input-21-c6102ec3f9bb>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# Conclusão: A **Biblioteca Central Zila Madane** é onde possui o maior número de emprestimos de toda a comunidade universitária da UFRN, nos últimos 10 anos.

# %% [markdown]
# #### Quais são os temas mais emprestados? E os menos?

# %%
cols = ['colecao','id_emprestimo']

graph3 = df1.loc[:,cols].groupby('colecao').count().sort_values('id_emprestimo', ascending=False).reset_index().head()
graph4 = df1.loc[:,cols].groupby('colecao').count().sort_values('id_emprestimo', ascending=True).reset_index().head()

print(f'O tema mais emprestado é {graph3.iloc[0,0]}, com {graph3.iloc[0,1]} emprestimos\nE o tema menos emprestado é {graph4.iloc[0,0]} com {graph4.iloc[0,1]} emprestimos.')
# Out:
# O tema mais emprestado é Acervo Circulante, com 2050272 emprestimos
# E o tema menos emprestado é Obras Raras com 8 emprestimos.

# %% [markdown]
# ### Criando uma nova coluna no conjunto de dados (Dia 2: Limpeza dos dados)

# %% [markdown]
# Os itens do acervo em uma biblioteca são organizados por um sistema de classificação de acordo com o respectivo tema. Existem diversos sistemas, mas este conjunto está de acordo com a CDU - Classificação Decimal Universal. Esta classificação é decimal, pois varia de acordo com a classe de cada assunto.

# %% [markdown]
# - 000 a 099: Generalidades. Ciência e conhecimento.
# - 100 a 199: Filosofia e psicologia.
# - 200 a 299: Religião.
# - 300 a 399: Ciências sociais.
# - 400 a 499: Classe vaga. Provisoriamente não ocupada.
# - 500 a 599: Matemática e ciências naturais.
# - 600 a 699: Ciências aplicadas.
# - 700 a 799: Belas artes.
# - 800 a 899: Linguagem. Língua. Linguística.
# - 900 a 999: Geografia. Biografia. História.

# %%
df2 = df1.copy()

# %%
df2.head(2)
# Out:
#    id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 0         709684       L095049            NaT 2010-01-04 07:44:10.721
# 1         709684       L095049            NaT 2010-01-04 07:44:10.721
#
#            data_devolucao  matricula_ou_siape tipo_vinculo_usuario  \
# 0 2010-01-05 16:26:12.662        2.008023e+09   ALUNO DE GRADUAÇÃO
# 1 2010-01-05 16:26:12.662        2.008023e+09   ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao                      biblioteca  \
# 0        13259  Acervo Circulante  Biblioteca Central Zila Mamede
# 1        13259  Acervo Circulante  Biblioteca Central Zila Mamede
#
#   status_material  localizacao  registro_sistema
# 0         REGULAR          630              4225
# 1         REGULAR          630              4225

# %%
df2['CNU'] = df2['localizacao'].apply(lambda x: "Generalidades, Ciência e conhecimento" if x < 100 else "Filosofia e psicologia" if x < 200 else "Religião" if x < 300 else "Ciências sociais" if x < 400 else "Classe vaga. Provisoriamente não ocupada" if x < 500 else "Matemática e ciências naturais" if x < 600 else "Ciências aplicadas" if x < 700 else "Belas Artes" if x < 800 else "Linguagem, Língua e Linguística" if x < 900 else "Geografia, Biografia e História" )

# %%
df2.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709684       L095049                     NaT
# 2         726965       L095049 2010-03-31 12:41:08.684
# 3         709685       L167050                     NaT
# 4         709685       L167050                     NaT
#
#           data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 2 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366        2.009122e+09
# 3 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# 4 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 3      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          630
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema                 CNU
# 0              4225  Ciências aplicadas
# 1              4225  Ciências aplicadas
# 2              4225  Ciências aplicadas
# 3             25009  Ciências aplicadas
# 4             25009  Ciências aplicadas

# %% [markdown]
# ### Removendo a coluna "registro_sistema"

# %%
df2 = df2.drop(columns="registro_sistema")

# %%
df2.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709684       L095049                     NaT
# 2         726965       L095049 2010-03-31 12:41:08.684
# 3         709685       L167050                     NaT
# 4         709685       L167050                     NaT
#
#           data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 2 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366        2.009122e+09
# 3 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# 4 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 3      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          630
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#                   CNU
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas

# %% [markdown]
# ### Transformando o tipo dos dados de uma coluna

# %%
df2.matricula_ou_siape = df2.matricula_ou_siape.astype(float)

# %%
df2.dtypes
# Out:
# id_emprestimo                    int64
# codigo_barras                   object
# data_renovacao          datetime64[ns]
# data_emprestimo         datetime64[ns]
# data_devolucao          datetime64[ns]
# matricula_ou_siape             float64
# tipo_vinculo_usuario            object
# id_exemplar                      int64
# colecao                         object
# biblioteca                      object
# status_material                 object
# localizacao                      int64
# CNU                             object
# dtype: object
